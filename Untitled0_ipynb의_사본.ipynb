# %% [markdown]
# <a href="https://colab.research.google.com/github/dukc11coco-hash/wassup13/blob/main/Untitled0_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
https://apis.data.go.kr/B551011/KorPetTourService2
service_key = "c36f20fa8e010928512eff06c66f392b85ff6fc698dde757ce93564d10b03e97"

url = "https://apis.data.go.kr/B551011/KorPetTourService2/areaBasedList2"

params = {
    "serviceKey": service_key,
    "numOfRows": 5,
    "pageNo": 1,
    "MobileOS": "ETC",
    "MobileApp": "AppTest",
    "areaCode": 1,   # 서울
    "_type": "json"
}

response = requests.get(url, params=params)

print("Status Code:", response.status_code)
print(response.text)
# Out:
#   File "/tmp/ipython-input-2664541964.py", line 2
#     https://apis.data.go.kr/B551011/KorPetTourService2
#           ^
# SyntaxError: invalid syntax

# %%
import requests

# 서비스 키
service_key = "c36f20fa8e010928512eff06c66f392b85ff6fc698dde757ce93564d10b03e97"

# 기본 URL
url = "https://apis.data.go.kr/B551011/KorPetTourService2/serviceKey"

# 파라미터
params = {
    "serviceKey": service_key,
    "numOfRows": 10,
    "pageNo": 1,
    "_type": "json"
}

response = requests.get(url, params=params)

print(response.status_code)
print(response.text)

# %%
import requests

service_key = "c36f20fa8e010928512eff06c66f392b85ff6fc698dde757ce93564d10b03e97"

url = "http://apis.data.go.kr/B551011/KorPetTourService2/areaBasedList2"

params = {
    "serviceKey": service_key,
    "MobileOS": "ETC",      # 필수인 경우가 많음
    "MobileApp": "ColabTest",
    "_type": "json",
    "numOfRows": 5,
    "pageNo": 1,
}

r = requests.get(url, params=params, timeout=20)

print("status:", r.status_code)
print("final url:", r.url)
print(r.text[:1000])

# %%
import requests

service_key = "여기에_네_키"
url = "http://apis.data.go.kr/B551011/KorPetTourService2/areaBasedList2"

params = {
    "serviceKey": service_key,
    "MobileOS": "ETC",
    "MobileApp": "ColabTest",
    "_type": "json",
    "numOfRows": 10,
    "pageNo": 1,
}

r = requests.get(url, params=params, timeout=20)
data = r.json()

items = data["response"]["body"]["items"]["item"]

# 핵심 필드만 출력
for it in items[:5]:
    title = it.get("title")
    addr = it.get("addr1")
    tel = it.get("tel")
    print(f"- {title} | {addr} | {tel}")

# %%
print(r.status_code)
print(r.text[:500])
# Out:
# 401
# Unauthorized

# %%
import requests

service_key = "c36f20fa8e010928512eff06c66f392b85ff6fc698dde757ce93564d10b03e97"  # (대부분 'Decoding' 키가 잘 됨)

base = "http://apis.data.go.kr/B551011/KorPetTourService2/areaBasedList2"
url = f"{base}?serviceKey={service_key}"

params = {
    "MobileOS": "ETC",
    "MobileApp": "ColabTest",
    "_type": "json",
    "numOfRows": 5,
    "pageNo": 1,
}

r = requests.get(url, params=params, timeout=20)

print("status:", r.status_code)
print("content-type:", r.headers.get("Content-Type"))
print(r.text[:500])
# Out:
# status: 200
# content-type: application/json
# {"response": {"header":{"resultCode":"0000","resultMsg":"OK"},"body": {"items": {"item":[{"addr1":"부산광역시 부산진구 가야대로 779 (부전동)","addr2":"","areacode":"","cat1":"","cat2":"","cat3":"","contentid":"2930927","contenttypeid":"38","createdtime":"20221030154457","firstimage":"https://tong.visitkorea.or.kr/cms/resource/49/2885349_image2_1.jpg","firstimage2":"https://tong.visitkorea.or.kr/cms/resource/49/2885349_image3_1.jpg","cpyrhtDivCd":"Type3","mapx":"129.056805686045","mapy":"35.1579550616706","mleve

# %%
import requests
import pandas as pd

service_key = "여기에_네_키"

base = "http://apis.data.go.kr/B551011/KorPetTourService2/areaBasedList2"
url = f"{base}?serviceKey={service_key}"

params = {
    "MobileOS": "ETC",
    "MobileApp": "ColabTest",
    "_type": "json",
    "numOfRows": 10,
    "pageNo": 1,
}

r = requests.get(url, params=params, timeout=20)
data = r.json()

items = data["response"]["body"]["items"]["item"]

df = pd.DataFrame(items)

# 필요한 컬럼만 보기 (없을 수도 있어서 있는 것만 골라줌)
cols = [c for c in ["title","addr1","tel","mapx","mapy","contentid","contenttypeid"] if c in df.columns]
df[cols].head(10)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/requests/models.py in json(self, **kwargs)
#     975         try:
# --> 976             return complexjson.loads(self.text, **kwargs)
#     977         except JSONDecodeError as e:
#
# /usr/local/lib/python3.12/dist-packages/simplejson/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, use_decimal, allow_nan, **kw)
#     513             and not use_decimal and not allow_nan and not kw):
# --> 514         return _default_decoder.decode(s)
#     515     if cls is None:
#
# /usr/local/lib/python3.12/dist-packages/simplejson/decoder.py in decode(self, s, _w, _PY3)
#     385             s = str(s, self.encoding)
# --> 386         obj, end = self.raw_decode(s)
#     387         end = _w(s, end).end()
#
# /usr/local/lib/python3.12/dist-packages/simplejson/decoder.py in raw_decode(self, s, idx, _w, _PY3)
#     415                 idx += 3
# --> 416         return self.scan_once(s, idx=_w(s, idx).end())
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# /tmp/ipython-input-4279663747.py in <cell line: 0>()
#      16
#      17 r = requests.get(url, params=params, timeout=20)
# ---> 18 data = r.json()
#      19
#      20 items = data["response"]["body"]["items"]["item"]
#
# /usr/local/lib/python3.12/dist-packages/requests/models.py in json(self, **kwargs)
#     978             # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979             # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 980             raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#     981
#     982     @property
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
JSONDecodeError                           Traceback (most recent call last)
/usr/local/lib/python3.12/dist-packages/requests/models.py in json(self, **kwargs)
    975         try:
--> 976             return complexjson.loads(self.text, **kwargs)
    977         except JSONDecodeError as e:

4 frames
JSONDecodeError: Expecting value: line 1 column 1 (char 0)

During handling of the above exception, another exception occurred:

JSONDecodeError                           Traceback (most recent call last)
/usr/local/lib/python3.12/dist-packages/requests/models.py in json(self, **kwargs)
    978             # Catch JSON-related errors and raise as requests.JSONDecodeError
    979             # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
--> 980             raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
    981
    982     @property

JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
if "json" in r.headers.get("Content-Type", ""):
    data = r.json()
    print("JSON 성공")
else:
    print("JSON 아님, 응답 내용 확인 필요")
    print(r.text[:500])

# %%
import requests, pandas as pd

service_key = "c36f20fa8e010928512eff06c66f392b85ff6fc698dde757ce93564d10b03e97"  # Decoding 키 추천

base = "http://apis.data.go.kr/B551011/KorPetTourService2/areaBasedList2"
url = f"{base}?serviceKey={service_key}"

params = {
    "MobileOS": "ETC",
    "MobileApp": "ColabTest",
    "_type": "json",
    "numOfRows": 10,
    "pageNo": 1,
}

r = requests.get(url, params=params, timeout=20)

print("status:", r.status_code)
print("final url:", r.url)
print("content-type:", r.headers.get("Content-Type"))
print("preview:", r.text[:120])

# 200일 때만 JSON 파싱
if r.status_code == 200 and "json" in (r.headers.get("Content-Type") or ""):
    data = r.json()
    items = data["response"]["body"]["items"]["item"]
    df = pd.DataFrame(items)
    display(df[["title","addr1","tel"]].head(10))
else:
    print("❗인증/요청 문제. 위 final url/preview 확인!")

# %%
seoul = df[df["addr1"].fillna("").str.contains("서울")]
seoul[["title","addr1","tel"]].head(20)

# %%
busan = df[df["addr1"].fillna("").str.contains("부산")]
busan[["title","addr1","tel"]].head(20)

# %%
df[df["title"].fillna("").str.contains("카페")][["title","addr1","tel"]].head(20)

# %%
import folium
from folium.plugins import MarkerCluster
import pandas as pd

# 좌표 컬럼을 숫자로 변환 (문자열로 오는 경우가 많음)
df2 = df.copy()
df2["mapx"] = pd.to_numeric(df2.get("mapx"), errors="coerce")
df2["mapy"] = pd.to_numeric(df2.get("mapy"), errors="coerce")

# 좌표 있는 것만
df2 = df2.dropna(subset=["mapx", "mapy"])

# 너무 많으면 느려서 200개만(원하면 숫자 바꿔도 됨)
df_plot = df2.head(50)

# 중심점(평균)으로 지도 시작
center_lat = df_plot["mapy"].mean()
center_lon = df_plot["mapx"].mean()

m = folium.Map(location=[center_lat, center_lon], zoom_start=7)

cluster = MarkerCluster().add_to(m)

for _, row in df_plot.iterrows():
    title = row.get("title", "")
    addr = row.get("addr1", "")
    tel = row.get("tel", "")

    popup = folium.Popup(f"<b>{title}</b><br>{addr}<br>{tel}", max_width=300)
    folium.Marker(
        location=[row["mapy"], row["mapx"]],
        popup=popup
    ).add_to(cluster)

m
